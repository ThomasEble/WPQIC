# %%
from qiskit_metal import designs, MetalGUI
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
import pyEPR as epr

design = designs.DesignPlanar()
design.chips.main.size.size_x = '9mm'
design.chips.main.size.size_y = '6mm'

try:
    gui.main_window.force_close = True
    gui.main_window.close()
except (NameError, AttributeError):
    pass

# Two open terminations — the ends of the resonator
otg1 = OpenToGround(design, 'OTG1', options=dict(pos_x='-1.5mm', pos_y='0mm', orientation='180'))
otg2 = OpenToGround(design, 'OTG2', options=dict(pos_x='1.5mm', pos_y='0mm', orientation='0'))

# CPW meander between them — length sets resonant frequency
# ~8mm total length → ~6 GHz for silicon substrate (εr=11.9)
res = RouteMeander(design, 'resonator', options=dict(
    pin_inputs=dict(
        start_pin=dict(component='OTG1', pin='open'),
        end_pin=dict(component='OTG2', pin='open'),
    ),
    total_length='8mm',
    fillet='90um',
    lead=dict(start_straight='300um', end_straight='300um'),
))

design.rebuild()

gui = MetalGUI(design)
gui.rebuild()
gui.autoscale()

pinfo = epr.ProjectInfo(
    project_path=r'C:\Users\labuser\Documents\Ansoft\Thomas',
    project_name='bandpass_CPW',
    design_name='lowpass_CPW'
)

hfss = design.renderers.hfss
hfss.start()
hfss.render_design()
# Out:
# INFO 08:33PM [connect_project]: Connecting to Ansys Desktop API...
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 38
#      35 gui.rebuild()
#      36 gui.autoscale()
# ---> 38 pinfo = epr.ProjectInfo(
#      39     project_path=r'C:\Users\labuser\Documents\Ansoft\Thomas',
#      40     project_name='bandpass_CPW',
#      41     design_name='lowpass_CPW'
#      42 )
#      44 hfss = design.renderers.hfss
#      45 hfss.start()
#
# File c:\Users\labuser\miniconda3\envs\metal\lib\site-packages\pyEPR\project_info.py:224, in ProjectInfo.__init__(self, project_path, project_name, design_name, setup_name, dielectrics_bulk, dielectric_surfaces, resistive_surfaces, seams, do_connect)
#     221 self.setup = None
#     223 if do_connect:
# --> 224     self.connect()
#     225     self.dissipative['pinfo'] = self
#
# File c:\Users\labuser\miniconda3\envs\metal\lib\site-packages\pyEPR\project_info.py:360, in ProjectInfo.connect(self)
#     354 def connect(self):
#     355     """
#     356     Do establish connection to Ansys desktop.
#     357     Connects to project and then get design and setup
#     358     """
# --> 360     self.connect_project()
#     361     if not self.project:
#     362         logger.info('\tConnection to Ansys NOT established.  \n')
#
# File c:\Users\labuser\miniconda3\envs\metal\lib\site-packages\pyEPR\project_info.py:254, in ProjectInfo.connect_project(self)
#     245 """Sets
#     246 self.app
#     247 self.desktop
#    (...)
#     250 self.project_path
#     251 """
#     252 logger.info('Connecting to Ansys Desktop API...')
# --> 254 self.app, self.desktop, self.project = ansys.load_ansys_project(
#     255     self.project_name, self.project_path)
#     257 if self.project:
#     258     # TODO: should be property?
#     259     self.project_name = self.project.name
#
# File c:\Users\labuser\miniconda3\envs\metal\lib\site-packages\pyEPR\ansys.py:3232, in load_ansys_project(proj_name, project_path, extension)
#    3230     logger.info('\tFile path to HFSS project found.')
#    3231 else:
# -> 3232     raise Exception(
#    3233         "ERROR! Valid directory, but invalid project filename. \N{loudly crying face} Not found!\
#    3234              Please check your filename.\n%s\n" % project_path)
#    3236 if (project_path / '.lock').is_file():
#    3237     logger.warning(
#    3238         '\t\tFile is locked. \N{fearful face} If connection fails, delete the .lock file.'
#    3239     )
#
# Exception: ERROR! Valid directory, but invalid project filename. 😭 Not found!                     Please check your filename.
# C:\Users\labuser\Documents\Ansoft\Thomas\bandpass_CPW.aedt
