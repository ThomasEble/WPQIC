# %%
# So, let us dive right in. For convenience, let's begin by enabling
# automatic reloading of modules when they change.
# %load_ext autoreload
# %autoreload 2

# %%
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs
from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket
# Packages for the simple design
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.tlines.pathfinder import RoutePathfinder
from qiskit_metal.qlibrary.terminations.launchpad_wb_driven import LaunchpadWirebondDriven
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
from qiskit_metal.qlibrary.couplers.coupled_line_tee import CoupledLineTee
from qiskit_metal.qlibrary.qubits.transmon_pocket_teeth import TransmonPocketTeeth
from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond
from qiskit_metal.qlibrary.qubits.transmon_pocket_6 import TransmonPocket6
from collections import OrderedDict
design = designs.DesignPlanar()
gui = MetalGUI(design)
design.overwrite_enabled = True

# %%
design.chips.main.size.size_x = '5mm'
design.chips.main.size.size_y = '5mm'
design.chips.main.size.size_z = '-380um'
design.chips.main.size.sample_holder_top='2mm'
design.chips.main.size.sample_holder_bottom='380um'

tl_width = '15.5um'
tl_gap = '9um'

# %% [markdown]
# ## Launch pads

# %%
lp_width = '180um'
lp_gap = '140um'

LP1 = LaunchpadWirebondDriven(design,name='LP1',
                       options={'orientation': '0', 'pos_x': '-2.1mm', 'pos_y': '0mm','pad_width':lp_width ,'pad_gap':lp_gap ,'pad_height':'180um', 'trace_width': tl_width , 'trace_gap': tl_gap},
                       component_template={'falseparam1': {'falseparam2': 'false-param', 'falseparam3': 'false-param'}},
                                        )




LP2 = LaunchpadWirebondDriven(design,name='LP2',
                       options={'orientation': '180', 'pos_x': '2.1mm', 'pos_y': '0mm','pad_width':lp_width ,'pad_gap':lp_gap, 'pad_height':'180um', 'trace_width':tl_width , 'trace_gap': tl_gap},
                       component_template={'falseparam1': {'falseparam2': 'false-param', 'falseparam3': 'false-param'}},
                                        )

gui.rebuild()
gui.autoscale()

# %% [markdown]
# ## Resonator 1

# %%
rr_width = tl_width
rr_gap = tl_gap
rr_coupling_gap = '15um' 
rr_coupling_length = '150um'
rr_termination = rr_gap


OTG1 = OpenToGround(design,name='OTG1'
                 ,options={'pos_x':'-1.5mm','pos_y':'-1.4mm','orientation':'-90','width':rr_width, 'gap':rr_gap, 'termination_gap': rr_termination })


q_read1 = CoupledLineTee(design,'Q_Read1', options=dict(pos_x = '-1.7mm', pos_y = '0mm',
                                                        prime_width=tl_width,
                                                        prime_gap=tl_gap,
                                                        second_width=rr_width,
                                                        second_gap=rr_gap,
                                                        fillet='50um',
                                                        mirror=True,
                                                        orientation = '0',
                                                        coupling_space = rr_coupling_gap,                                                         
                                                        coupling_length = rr_coupling_length,
                                                        open_termination = False))

RR1 = RouteMeander(design, 'RR1',  Dict(
        trace_width =tl_width,
        trace_gap =tl_gap,
        total_length='3mm',
        hfss_wire_bonds = False,
        fillet='50 um',
        lead = dict(start_straight='100um',end_straight='10um'),
        meander= dict(spacing='150um',asymmetry='200um'),
        pin_inputs=Dict(
            start_pin=Dict(component='Q_Read1', pin='second_end'),
            end_pin=Dict(component='OTG1', pin='open')), ))

gui.rebuild()
gui.autoscale()

# %% [markdown]
# ## Resonator 2

# %%
rr_width = tl_width
rr_gap = tl_gap
rr_coupling_gap = '15um' 
rr_coupling_length = '150um'
rr_termination = rr_gap

OTG2 = OpenToGround(design,name='OTG2'
                 ,options={'pos_x':'-1.4mm','pos_y':'1.4mm','orientation':'90','width':tl_width, 'gap':tl_gap, 'termination_gap': tl_gap })


q_read2 = CoupledLineTee(design,'Q_Read2', options=dict(pos_x = '-1.1mm', pos_y = '0mm',
                                                        prime_width=tl_width,
                                                        prime_gap=tl_gap,
                                                        second_width=rr_width,
                                                        second_gap=rr_gap,
                                                        fillet='50um',
                                                        mirror=True,
                                                        orientation = '180',
                                                        coupling_space = rr_coupling_gap,                                                         
                                                        coupling_length = rr_coupling_length,
                                                        open_termination = False))

RR2 = RouteMeander(design, 'RR2',  Dict(
        trace_width =tl_width,
        trace_gap =tl_gap,
        total_length='3.2mm',
        hfss_wire_bonds = False,
        fillet='50 um',
        lead = dict(start_straight='100um',end_straight='10um'),
        meander= dict(spacing='150um',asymmetry='200um'),
        pin_inputs=Dict(
            start_pin=Dict(component='Q_Read2', pin='second_end'),
            end_pin=Dict(component='OTG2', pin='open')), ))

gui.rebuild()
gui.autoscale()

# %% [markdown]
# ## Resonator 3

# %%
rr_width = tl_width
rr_gap = tl_gap
rr_coupling_gap = '15um' 
rr_coupling_length = '150um'
rr_termination = rr_gap

OTG3 = OpenToGround(design,name='OTG3'
                 ,options={'pos_x':'0.05mm','pos_y':'-1.4mm','orientation':'-90','width':tl_width, 'gap':tl_gap, 'termination_gap': tl_gap })


q_read3 = CoupledLineTee(design,'Q_Read3', options=dict(pos_x = '-0.3mm', pos_y = '0mm',
                                                        prime_width=tl_width,
                                                        prime_gap=tl_gap,
                                                        second_width=rr_width,
                                                        second_gap=rr_gap,
                                                        fillet='50um',
                                                        mirror=True,
                                                        orientation = '0',
                                                        coupling_space = rr_coupling_gap,                                                         
                                                        coupling_length = rr_coupling_length,
                                                        open_termination = False))

RR3 = RouteMeander(design, 'RR3',  Dict(
        trace_width =tl_width,
        trace_gap =tl_gap,
        total_length='3.4mm',
        hfss_wire_bonds = False,
        fillet='50 um',
        lead = dict(start_straight='100um',end_straight='10um'),
        meander= dict(spacing='150um',asymmetry='200um'),
        pin_inputs=Dict(
            start_pin=Dict(component='Q_Read3', pin='second_end'),
            end_pin=Dict(component='OTG3', pin='open')), ))

gui.rebuild()
gui.autoscale()

# %% [markdown]
# ## Resonator 4

# %%
rr_width = tl_width
rr_gap = tl_gap
rr_coupling_gap = '15um' 
rr_coupling_length = '150um'
rr_termination = rr_gap

OTG4 = OpenToGround(design,name='OTG4'
                 ,options={'pos_x':'-0.05mm','pos_y':'+1.4mm','orientation':'90','width':tl_width, 'gap':tl_gap, 'termination_gap': tl_gap})


q_read4 = CoupledLineTee(design,'Q_Read4', options=dict(pos_x = '0.3mm', pos_y = '0mm',
                                                        prime_width=tl_width,
                                                        prime_gap=tl_gap,
                                                        second_width=rr_width,
                                                        second_gap=rr_gap,
                                                        fillet='50um',
                                                        mirror=True,
                                                        orientation = '180',
                                                        coupling_space = rr_coupling_gap,                                                         
                                                        coupling_length = rr_coupling_length,
                                                        open_termination = False))

RR4 = RouteMeander(design, 'RR4',  Dict(
        trace_width =tl_width,
        trace_gap =tl_gap,
        total_length='3.6mm',
        hfss_wire_bonds = False,
        fillet='50 um',
        lead = dict(start_straight='100um',end_straight='10um'),
        meander= dict(spacing='150um',asymmetry='200um'),
        pin_inputs=Dict(
            start_pin=Dict(component='Q_Read4', pin='second_end'),
            end_pin=Dict(component='OTG4', pin='open')), ))

gui.rebuild()
gui.autoscale()

# %% [markdown]
# ## Resonator 5

# %%
rr_width = tl_width
rr_gap = tl_gap
rr_coupling_gap = '15um' 
rr_coupling_length = '150um'
rr_termination = rr_gap

OTG5 = OpenToGround(design,name='OTG5'
                 ,options={'pos_x':'1.5mm','pos_y':'-1.4mm','orientation':'-90','width':tl_width, 'gap':tl_gap, 'termination_gap': tl_gap})


q_read5 = CoupledLineTee(design,'Q_Read5', options=dict(pos_x = '1.1mm', pos_y = '0mm',
                                                        prime_width=tl_width,
                                                        prime_gap=tl_gap,
                                                        second_width=rr_width,
                                                        second_gap=rr_gap,
                                                        fillet='50um',
                                                        mirror=True,
                                                        orientation = '0',
                                                        coupling_space = rr_coupling_gap,                                                         
                                                        coupling_length = rr_coupling_length,
                                                        open_termination = False))

RR5 = RouteMeander(design, 'RR5',  Dict(
        trace_width =tl_width,
        trace_gap =tl_gap,
        total_length='3.8mm',
        hfss_wire_bonds = False,
        fillet='50 um',
        lead = dict(start_straight='100um',end_straight='10um'),
        meander= dict(spacing='150um',asymmetry='200um'),
        pin_inputs=Dict(
            start_pin=Dict(component='Q_Read5', pin='second_end'),
            end_pin=Dict(component='OTG5', pin='open')), ))

gui.rebuild()
gui.autoscale()

# %% [markdown]
# ## Resonator 6

# %%
rr_width = tl_width
rr_gap = tl_gap
rr_coupling_gap = '15um' 
rr_coupling_length = '150um'
rr_termination = rr_gap

OTG6 = OpenToGround(design,name='OTG6'
                 ,options={'pos_x':'1.4mm','pos_y':'1.4mm','orientation':'90','width':tl_width, 'gap':tl_gap, 'termination_gap': tl_gap})


q_read6 = CoupledLineTee(design,'Q_Read6', options=dict(pos_x = '1.7mm', pos_y = '0mm',
                                                        prime_width=tl_width,
                                                        prime_gap=tl_gap,
                                                        second_width=rr_width,
                                                        second_gap=rr_gap,
                                                        fillet='50um',
                                                        mirror=True,
                                                        orientation = '180',
                                                        coupling_space = rr_coupling_gap,                                                         
                                                        coupling_length = rr_coupling_length,
                                                        open_termination = False))

RR6 = RouteMeander(design, 'RR6',  Dict(
        trace_width =tl_width,
        trace_gap =tl_gap,
        total_length='4mm',
        hfss_wire_bonds = False,
        fillet='50 um',
        lead = dict(start_straight='100um',end_straight='10um'),
        meander= dict(spacing='150um',asymmetry='200um'),
        pin_inputs=Dict(
            start_pin=Dict(component='Q_Read6', pin='second_end'),
            end_pin=Dict(component='OTG6', pin='open')), ))

gui.rebuild()
gui.autoscale()

# %% [markdown]
# ## Segments

# %%
seg1 = RoutePathfinder(design, 'seg1', options = dict(chip='main', 
                                                      trace_width =tl_width,
                                                      trace_gap =tl_gap,
                                                      fillet='100um',
                                                      hfss_wire_bonds = True,
                                                    lead=dict(start_straight = '0mm',
                                                        end_straight='0mm'),
                                                        pin_inputs=dict(
                                                        start_pin=dict(
                                                                component='Q_Read1',
                                                                pin='prime_start'),
                                                       end_pin=dict(
                                                        component='LP1',
                                                        pin='tie')
                                                 )))



seg2 = RoutePathfinder(design, 'seg2', options = dict(chip='main', 
                                                      trace_width =tl_width,
                                                      trace_gap =tl_gap,
                                                      fillet='100um',
                                                      hfss_wire_bonds = True,
                                                    lead=dict(start_straight = '0mm',
                                                        end_straight='0mm'),
                                                        pin_inputs=dict(
                                                        start_pin=dict(
                                                                component='Q_Read2',
                                                                pin='prime_end'),
                                                       end_pin=dict(
                                                        component='Q_Read1',
                                                        pin='prime_end')
                                                 )))

seg3 = RoutePathfinder(design, 'seg3', options = dict(chip='main', 
                                                      trace_width =tl_width,
                                                      trace_gap =tl_gap,
                                                      fillet='100um',
                                                      hfss_wire_bonds = True,
                                                    lead=dict(start_straight = '0mm',
                                                        end_straight='0mm'),
                                                        pin_inputs=dict(
                                                        start_pin=dict(
                                                                component='Q_Read3',
                                                                pin='prime_start'),
                                                       end_pin=dict(
                                                        component='Q_Read2',
                                                        pin='prime_start')
                                                 )))

seg4 = RoutePathfinder(design, 'seg4', options = dict(chip='main', 
                                                      trace_width =tl_width,
                                                      trace_gap =tl_gap,
                                                      fillet='100um',
                                                      hfss_wire_bonds = True,
                                                    lead=dict(start_straight = '0mm',
                                                        end_straight='0mm'),
                                                        pin_inputs=dict(
                                                        start_pin=dict(
                                                                component='Q_Read3',
                                                                pin='prime_end'),
                                                       end_pin=dict(
                                                        component='Q_Read4',
                                                        pin='prime_end')
                                                 )))

seg5 = RoutePathfinder(design, 'seg5', options = dict(chip='main', 
                                                      trace_width =tl_width,
                                                      trace_gap =tl_gap,
                                                      fillet='100um',
                                                      hfss_wire_bonds = True,
                                                    lead=dict(start_straight = '0mm',
                                                        end_straight='0mm'),
                                                        pin_inputs=dict(
                                                        start_pin=dict(
                                                                component='Q_Read4',
                                                                pin='prime_start'),
                                                       end_pin=dict(
                                                        component='Q_Read5',
                                                        pin='prime_start')
                                                 )))

seg6 = RoutePathfinder(design, 'seg6', options = dict(chip='main', 
                                                      trace_width =tl_width,
                                                      trace_gap =tl_gap,
                                                      fillet='100um',
                                                      hfss_wire_bonds = True,
                                                    lead=dict(start_straight = '0mm',
                                                        end_straight='0mm'),
                                                        pin_inputs=dict(
                                                        start_pin=dict(
                                                                component='Q_Read5',
                                                                pin='prime_end'),
                                                       end_pin=dict(
                                                        component='Q_Read6',
                                                        pin='prime_end')
                                                 )))

seg7 = RoutePathfinder(design, 'seg7', options = dict(chip='main', 
                                                      trace_width =tl_width,
                                                      trace_gap =tl_gap,
                                                      fillet='100um',
                                                      hfss_wire_bonds = True,
                                                    lead=dict(start_straight = '0mm',
                                                        end_straight='0mm'),
                                                        pin_inputs=dict(
                                                        start_pin=dict(
                                                                component='Q_Read6',
                                                                pin='prime_start'),
                                                       end_pin=dict(
                                                        component='LP2',
                                                        pin='tie')
                                                 )))

gui.rebuild()
gui.autoscale()
